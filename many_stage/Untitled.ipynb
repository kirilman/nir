# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
signals = np.load('signals.npy')

# %%
signals.shape
# Out:
# (33, 2000)

# %%
fig = plt.figure(dpi = 150, figsize=( 15, 4))
plt.plot(signals[2])
plt.plot(signals[0],'g')
plt.plot(signals[4],'r')

# %%
plt.plot(signals[4])
